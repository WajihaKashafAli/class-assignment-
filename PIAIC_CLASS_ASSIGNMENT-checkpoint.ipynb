# %%
class_1 = {
    "name" : "AI"
}

class_2 = {
    "name" : "CNC"
}

Students = {
    "student_01" :
    {
        "name" : "Kashaf",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        "class_cnc" : class_2,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_02" :
    {
        "name" : "Wajiha",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        
        "class_cnc" : class_2,
        "marks_cnc" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_03" :
    {
        "name" : "Talha",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        "class_cnc" : class_2,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_04" :
    {
        "name" : "Affan",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        
        "class_cnc" : class_2,
        "marks_cnc" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_05" :
    {
        "name" : "Shahzad",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        "class_cnc" : class_2,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_06" :
    {
        "name" : "ahsan",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        
        "class_cnc" : class_2,
        "marks_cnc" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_07" :
    {
        "name" : "Fozan",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        "class_cnc" : class_2,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_08" :
    {
        "name" : "Arham",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        
        "class_cnc" : class_2,
        "marks_cnc" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_09" :
    {
        "name" : "Mustufa",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        "class_cnc" : class_2,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
    "student_10" :
    {
        "name" : "Muhammad",
        "class_ai" : class_1,
        "marks_ai" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        },
        
        "class_cnc" : class_2,
        "marks_cnc" : 
        {
            "quiz_1" : 40,
            "quiz_2" : 45,
            "mid" : 50,
            "final" : 55,
        }
        
    },
    
}
    
Std_ID = input("Enter Std_ID: ")

Std_ID = "student_" + Std_ID

Std_class = input("Enter a Class(AI/CNC): ")

Std_class_1 = "marks_" + Std_class

Std_class_2 = "marks_" + Std_class

Std_Exam = input("enter a Exam name (quiz_1 / quiz_2 / mid / final): ")


print ("Marks of" , Students[Std_ID]["name"] , "in" , Std_class, Std_Exam , "exam is" , 
       Students[Std_ID][Std_class_1][Std_Exam])
# Out:
# Enter Std_ID: 06
# Enter a Class(AI/CNC): cnc
# enter a Exam name (quiz_1 / quiz_2 / mid / final): final
# Marks of ahsan in cnc final exam is 55
